# %% [markdown]
# https://towardsdatascience.com/an-extensive-guide-to-collecting-tweets-from-twitter-api-v2-for-academic-research-using-python-3-518fcb71df2a

# %%
# For sending GET requests from the API
import requests
# For saving access tokens and for file management when creating and adding to the dataset
import os
# For dealing with json responses we receive from the API
import json
# For displaying the data after
import pandas as pd
# For saving the response data in CSV format
import csv
# For parsing the dates received from twitter in readable formats
import datetime
import dateutil.parser
import unicodedata
#To add wait time between requests
import time

# %%
os.environ['TOKEN'] = 'AAAAAAAAAAAAAAAAAAAAAKVLfwEAAAAA9U65FTL2ZrQgx1u1kgA94uCDzt8%3D9g59OKwN90CZ3BeWlqsMQfoFkLzUWhk7oYfz5917X90ygMxium'

# %%
def auth():
    return os.getenv('TOKEN')

# %%
def create_headers(bearer_token):
    headers = {"Authorization": "Bearer {}".format(bearer_token)}
    return headers

# %%
def create_url(keyword, start_date, end_date, max_results = 10):
    
    search_url = "https://api.twitter.com/2/tweets/search/recent" #Change to the endpoint you want to collect data from

    #change params based on the endpoint you are using
    query_params = {'query': keyword,
                    'start_time': start_date,
                    'end_time': end_date,
                    'max_results': max_results,
                    'expansions': 'author_id,in_reply_to_user_id,geo.place_id',
                    'tweet.fields': 'id,text,author_id,in_reply_to_user_id,geo,conversation_id,created_at,lang,public_metrics,referenced_tweets,reply_settings,source',
                    'user.fields': 'id,name,username,created_at,description,public_metrics,verified',
                    'place.fields': 'full_name,id,country,country_code,geo,name,place_type',
                    'next_token': {}}
    return (search_url, query_params)

# %%
def connect_to_endpoint(url, headers, params, next_token = None):
    params['next_token'] = next_token   #params object received from create_url function
    response = requests.request("GET", url, headers = headers, params = params)
    print("Endpoint Response Code: " + str(response.status_code))
    if response.status_code != 200:
        raise Exception(response.status_code, response.text)
    return response.json()

# %%
#Inputs for the request
bearer_token = auth()
headers = create_headers(bearer_token)
keyword = "@hm (dress OR dresses OR shirt OR shirts OR pants OR skirt OR skirts OR clothes) lang:en -is:retweet"
start_time = "2022-08-12T00:00:00.000Z"
end_time = "2022-08-16T00:00:00.000Z"
max_results = 10

# %%
url = create_url(keyword, start_time,end_time, max_results)

# %%
json_response = connect_to_endpoint(url[0], headers, url[1])
# Out:
# Endpoint Response Code: 200

# %%
print(json.dumps(json_response, indent=4, sort_keys=True))
# Out:
# {
#     "data": [
#         {
#             "author_id": "1525515243912298499",
#             "conversation_id": "1559284907788083204",
#             "created_at": "2022-08-15T21:04:26.000Z",
#             "id": "1559284907788083204",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 4,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 1
#             },
#             "reply_settings": "everyone",
#             "source": "Twitter for iPhone",
#             "text": "Corinna Brown - Short twill skirt in black/white checked by @hm - https://t.co/sDY2CJMMWV https://t.co/ZDirTLevCR"
#         },
#         {
#             "author_id": "912295575697203201",
#             "conversation_id": "1559270690381086721",
#             "created_at": "2022-08-15T20:07:57.000Z",
#             "id": "1559270690381086721",
#             "in_reply_to_user_id": "14399483",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "reply_settings": "everyone",
#             "source": "Twitter for iPhone",
#             "text": "@hm when will the pants shown here be available online? https://t.co/pxlPkhUcKr"
#         },
#         {
#             "author_id": "1549124854812639232",
#             "conversation_id": "1559246999165206530",
#             "created_at": "2022-08-15T18:33:48.000Z",
#             "id": "1559246999165206530",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "reply_settings": "everyone",
#             "source": "Twitter for Android",
#             "text": "#outfitoftheday @Macys jewelry @Coach handbag @hm crochet top &amp; pants https://t.co/csuJfZSwvF"
#         },
#         {
#             "author_id": "1443595240137449472",
#             "conversation_id": "1559185096284016641",
#             "created_at": "2022-08-15T14:27:49.000Z",
#             "id": "1559185096284016641",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 3,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 1
#             },
#             "reply_settings": "everyone",
#             "source": "Twitter Web App",
#             "text": "Hot tip: @hm has a Garment Collection program where if you bring in old clothes of any condition/brand, you can get a discount (usually ~15%) coupon for your next purchase. Great way to recycle clothes that aren't eligible for donation!"
#         },
#         {
#             "author_id": "2283241081",
#             "conversation_id": "1559122718385385472",
#             "created_at": "2022-08-15T10:23:02.000Z",
#             "id": "1559123491324309504",
#             "in_reply_to_user_id": "2283241081",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 1,
#                 "retweet_count": 0
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1559122718385385472",
#                     "type": "replied_to"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter for iPhone",
#             "text": "My sister who loves @hm shops every month from the store here and has taken me along a bunch of times. \nI\u2019ve always faced problems with finding pants my size and this time I just had to do something about it. \n#plussizefashion #midsize #sizeinclusivity"
#         },
#         {
#             "author_id": "2426396108",
#             "conversation_id": "1558977104275918848",
#             "created_at": "2022-08-15T01:09:24.000Z",
#             "id": "1558984167085355008",
#             "in_reply_to_user_id": "2426396108",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1558981357530845184",
#                     "type": "replied_to"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter Web App",
#             "text": "3/ We gladly accept hand-me-ups from family &amp; friends these days due to rising charity &amp; tip shop textile prices. Free clothes are the way to go when there is so much textile waste - we're not shopping to keep it out of landfill at those prices. This @hm coat was our daughters. https://t.co/jjkWHAglO6"
#         },
#         {
#             "author_id": "87229885",
#             "conversation_id": "1558872612540907520",
#             "created_at": "2022-08-14T17:46:07.000Z",
#             "geo": {
#                 "coordinates": {
#                     "coordinates": [
#                         -2.2463,
#                         53.4793
#                     ],
#                     "type": "Point"
#                 },
#                 "place_id": "315b740b108481f6"
#             },
#             "id": "1558872612540907520",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "reply_settings": "everyone",
#             "source": "Instagram",
#             "text": "Here for linen, fresh whites and sandals \ud83d\udd4a\n\nshirt: @ukgap\nvest: @hm\ntrousers: @andotherstories\nsandals: @dune_london \nbag: @amazonfashioneu @ Manchester, United Kingdom https://t.co/TIgXs1k0z0"
#         },
#         {
#             "author_id": "419663786",
#             "conversation_id": "1558830828259385344",
#             "created_at": "2022-08-14T15:00:05.000Z",
#             "id": "1558830828259385344",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "reply_settings": "everyone",
#             "source": "Emplifi",
#             "text": "Life's a party, so dress for it!\n\nShirt, pants, sandals: @HM\nRing, watch: @Maisonsimons\n\n\ud83d\udcf8: @Tracey.jazmin\u2063\u2063\u2063\u2063\u2063\u2063\u2063\u2063\nModel: @lancedugay\u2063\u2063\u2063\u2063\u2063\u2063\n\ud83d\udccd: Glenora building \u2013 Former @royal_alberta_museum https://t.co/CVxV2dczOl"
#         },
#         {
#             "author_id": "1557223542625669121",
#             "conversation_id": "1558765315416174596",
#             "created_at": "2022-08-14T10:39:46.000Z",
#             "id": "1558765315416174596",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 13,
#                 "quote_count": 0,
#                 "reply_count": 1,
#                 "retweet_count": 5
#             },
#             "reply_settings": "everyone",
#             "source": "Twitter for Android",
#             "text": "Won the contest of the prettiest chick wearing @hm cute fits ! \nFashion styling Day2Night dress.  Nude colour casual dress truned into a sexy night club dress . Fashion Boss \ud83d\udc9c https://t.co/aCKc9GJh3j"
#         },
#         {
#             "author_id": "321152335",
#             "conversation_id": "1558647641663279108",
#             "created_at": "2022-08-14T02:52:10.000Z",
#             "id": "1558647641663279108",
#             "in_reply_to_user_id": "14399483",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "reply_settings": "everyone",
#             "source": "Twitter for iPhone",
#             "text": "@hm your baby clothes are going to be the reason I have to go back to work and not be a stay at home mom \ud83d\ude05"
#         }
#     ],
#     "includes": {
#         "places": [
#             {
#                 "country": "United Kingdom",
#                 "country_code": "GB",
#                 "full_name": "Manchester, England",
#                 "geo": {
#                     "bbox": [
#                         -2.319934,
#                         53.343623,
#                         -2.147026,
#                         53.5702824
#                     ],
#                     "properties": {},
#                     "type": "Feature"
#                 },
#                 "id": "315b740b108481f6",
#                 "name": "Manchester",
#                 "place_type": "city"
#             }
#         ],
#         "users": [
#             {
#                 "created_at": "2022-05-14T16:36:30.000Z",
#                 "description": "#1 source for all heartstopper cast and character clothing needs \ud83d\udc55\ud83d\udc56\ud83d\udc57\ud83d\udc5f",
#                 "id": "1525515243912298499",
#                 "name": "fashion of heartstopper",
#                 "public_metrics": {
#                     "followers_count": 179,
#                     "following_count": 19,
#                     "listed_count": 1,
#                     "tweet_count": 144
#                 },
#                 "username": "fashionofhs",
#                 "verified": false
#             },
#             {
#                 "created_at": "2017-09-25T12:39:49.000Z",
#                 "description": "Student & Muma \u2728",
#                 "id": "912295575697203201",
#                 "name": "Abigail",
#                 "public_metrics": {
#                     "followers_count": 4,
#                     "following_count": 6,
#                     "listed_count": 0,
#                     "tweet_count": 263
#                 },
#                 "username": "Abigail91127920",
#                 "verified": false
#             },
#             {
#                 "created_at": "2008-04-15T18:34:00.000Z",
#                 "description": "Welcome to our #HM world \u2013 we\u2019re all about fashion, fun and things that matter to us. Got a question? \ud83d\udc49@hm_custserv",
#                 "id": "14399483",
#                 "name": "H&M",
#                 "public_metrics": {
#                     "followers_count": 8011196,
#                     "following_count": 327,
#                     "listed_count": 10192,
#                     "tweet_count": 14001
#                 },
#                 "username": "hm",
#                 "verified": true
#             },
#             {
#                 "created_at": "2022-07-18T20:12:21.000Z",
#                 "description": "Outfit inspirations and styling tips",
#                 "id": "1549124854812639232",
#                 "name": "22 Pretty Things",
#                 "public_metrics": {
#                     "followers_count": 10,
#                     "following_count": 35,
#                     "listed_count": 0,
#                     "tweet_count": 29
#                 },
#                 "username": "22prettythings",
#                 "verified": false
#             },
#             {
#                 "created_at": "2021-09-30T15:15:34.000Z",
#                 "description": "\ud83d\udcb5 Wall Street Trader turned Finance Creator \ud83d\udcf1 2.5M BFFs on TikTok + IG \ud83d\uddde Ft. @Bloomberg, @YahooFinance, @CNBC, @NASDAQ \ud83d\udcbb",
#                 "id": "1443595240137449472",
#                 "name": "Your Rich BFF",
#                 "public_metrics": {
#                     "followers_count": 543,
#                     "following_count": 58,
#                     "listed_count": 1,
#                     "tweet_count": 346
#                 },
#                 "username": "Your_RichBFF",
#                 "verified": true
#             },
#             {
#                 "created_at": "2014-01-09T07:47:48.000Z",
#                 "description": "",
#                 "id": "2283241081",
#                 "name": "nishi john",
#                 "public_metrics": {
#                     "followers_count": 9,
#                     "following_count": 56,
#                     "listed_count": 1,
#                     "tweet_count": 28
#                 },
#                 "username": "nishijohn1",
#                 "verified": false
#             },
#             {
#                 "created_at": "2014-04-04T00:42:10.000Z",
#                 "description": "MIA's legacy project raises awareness of repair by sharing practical actions undertaken. We're advocating & campaigning for the right to repair #voicesforrepair",
#                 "id": "2426396108",
#                 "name": "Mend It, Australia is Karen and Danny Ellis",
#                 "public_metrics": {
#                     "followers_count": 1037,
#                     "following_count": 1088,
#                     "listed_count": 15,
#                     "tweet_count": 10044
#                 },
#                 "username": "MendItAussie",
#                 "verified": false
#             },
#             {
#                 "created_at": "2009-11-03T16:46:55.000Z",
#                 "description": "Content Creator.  Southerner living in the North. Contact: hannah-ivy@hotmail.com Instagram: @hannahivvy",
#                 "id": "87229885",
#                 "name": "Hannah Apps",
#                 "public_metrics": {
#                     "followers_count": 470,
#                     "following_count": 253,
#                     "listed_count": 27,
#                     "tweet_count": 2594
#                 },
#                 "username": "hannahivvy",
#                 "verified": false
#             },
#             {
#                 "created_at": "2011-11-23T16:45:05.000Z",
#                 "description": "Featuring a diverse mix of stores & services for your lifestyle!",
#                 "id": "419663786",
#                 "name": "Londonderry Mall",
#                 "public_metrics": {
#                     "followers_count": 1288,
#                     "following_count": 744,
#                     "listed_count": 25,
#                     "tweet_count": 4959
#                 },
#                 "username": "LondonderryMall",
#                 "verified": false
#             },
#             {
#                 "created_at": "2022-08-10T04:33:28.000Z",
#                 "description": "Fashion Stylist ! Expert in woman's clothing, Casual , baggy, cute ,boss outfits, latex outfits , dominatrix persona",
#                 "id": "1557223542625669121",
#                 "name": "Goddess Val",
#                 "public_metrics": {
#                     "followers_count": 55,
#                     "following_count": 72,
#                     "listed_count": 0,
#                     "tweet_count": 28
#                 },
#                 "username": "SuperiorDresses",
#                 "verified": false
#             },
#             {
#                 "created_at": "2011-06-21T03:18:27.000Z",
#                 "description": "There\u2019s a time to cry and right now isn\u2019t the time",
#                 "id": "321152335",
#                 "name": "teresa jasko",
#                 "public_metrics": {
#                     "followers_count": 518,
#                     "following_count": 278,
#                     "listed_count": 1,
#                     "tweet_count": 24827
#                 },
#                 "username": "teresaa_jasko",
#                 "verified": false
#             }
#         ]
#     },
#     "meta": {
#         "newest_id": "1559284907788083204",
#         "next_token": "b26v89c19zqg8o3fpz5nho3o2sarmyw82839y6zf73ji5",
#         "oldest_id": "1558647641663279108",
#         "result_count": 10
#     }
# }

# %%
json_response.keys()
# Out:
# dict_keys(['data', 'includes', 'meta'])

# %%
json_response['data']
# Out:
# [{'id': '1559284907788083204',
#   'created_at': '2022-08-15T21:04:26.000Z',
#   'author_id': '1525515243912298499',
#   'text': 'Corinna Brown - Short twill skirt in black/white checked by @hm - https://t.co/sDY2CJMMWV https://t.co/ZDirTLevCR',
#   'public_metrics': {'retweet_count': 1,
#    'reply_count': 0,
#    'like_count': 4,
#    'quote_count': 0},
#   'reply_settings': 'everyone',
#   'lang': 'en',
#   'source': 'Twitter for iPhone',
#   'conversation_id': '1559284907788083204'},
#  {'id': '1559270690381086721',
#   'in_reply_to_user_id': '14399483',
#   'created_at': '2022-08-15T20:07:57.000Z',
#   'author_id': '912295575697203201',
#   'text': '@hm when will the pants shown here be available online? https://t.co/pxlPkhUcKr',
#   'public_metrics': {'retweet_count': 0,
#    'reply_count': 0,
#    'like_count': 0,
#    'quote_count': 0},
#   'reply_settings': 'everyone',
#   'lang': 'en',
#   'source': 'Twitter for iPhone',
#   'conversation_id': '1559270690381086721'},
#  {'id': '1559246999165206530',
#   'created_at': '2022-08-15T18:33:48.000Z',
#   'author_id': '1549124854812639232',
#   'text': '#outfitoftheday @Macys jewelry @Coach handbag @hm crochet top &amp; pants https://t.co/csuJfZSwvF',
#   'public_metrics': {'retweet_count': 0,
#    'reply_count': 0,
#    'like_count': 0,
#    'quote_count': 0},
#   'reply_settings': 'everyone',
#   'lang': 'en',
#   'source': 'Twitter for Android',
#   'conversation_id': '1559246999165206530'},
#  {'id': '1559185096284016641',
#   'created_at': '2022-08-15T14:27:49.000Z',
#   'author_id': '1443595240137449472',
#   'text': "Hot tip: @hm has a Garment Collection program where if you bring in old clothes of any condition/brand, you can get a discount (usually ~15%) coupon for your next purchase. Great way to recycle clothes that aren't eligible for donation!",
#   'public_metrics': {'retweet_count': 1,
#    'reply_count': 0,
#    'like_count': 3,
#    'quote_count': 0},
#   'reply_settings': 'everyone',
#   'lang': 'en',
#   'source': 'Twitter Web App',
#   'conversation_id': '1559185096284016641'},
#  {'id': '1559123491324309504',
#   'in_reply_to_user_id': '2283241081',
#   'referenced_tweets': [{'type': 'replied_to', 'id': '1559122718385385472'}],
#   'created_at': '2022-08-15T10:23:02.000Z',
#   'author_id': '2283241081',
#   'text': 'My sister who loves @hm shops every month from the store here and has taken me along a bunch of times. \nI’ve always faced problems with finding pants my size and this time I just had to do something about it. \n#plussizefashion #midsize #sizeinclusivity',
#   'public_metrics': {'retweet_count': 0,
#    'reply_count': 1,
#    'like_count': 0,
#    'quote_count': 0},
#   'reply_settings': 'everyone',
#   'lang': 'en',
#   'source': 'Twitter for iPhone',
#   'conversation_id': '1559122718385385472'},
#  {'id': '1558984167085355008',
#   'in_reply_to_user_id': '2426396108',
#   'referenced_tweets': [{'type': 'replied_to', 'id': '1558981357530845184'}],
#   'created_at': '2022-08-15T01:09:24.000Z',
#   'author_id': '2426396108',
#   'text': "3/ We gladly accept hand-me-ups from family &amp; friends these days due to rising charity &amp; tip shop textile prices. Free clothes are the way to go when there is so much textile waste - we're not shopping to keep it out of landfill at those prices. This @hm coat was our daughters. https://t.co/jjkWHAglO6",
#   'public_metrics': {'retweet_count': 0,
#    'reply_count': 0,
#    'like_count': 0,
#    'quote_count': 0},
#   'reply_settings': 'everyone',
#   'lang': 'en',
#   'source': 'Twitter Web App',
#   'conversation_id': '1558977104275918848'},
#  {'id': '1558872612540907520',
#   'created_at': '2022-08-14T17:46:07.000Z',
#   'author_id': '87229885',
#   'text': 'Here for linen, fresh whites and sandals 🕊\n\nshirt: @ukgap\nvest: @hm\ntrousers: @andotherstories\nsandals: @dune_london \nbag: @amazonfashioneu @ Manchester, United Kingdom https://t.co/TIgXs1k0z0',
#   'public_metrics': {'retweet_count': 0,
#    'reply_count': 0,
#    'like_count': 0,
#    'quote_count': 0},
#   'reply_settings': 'everyone',
#   'lang': 'en',
#   'source': 'Instagram',
#   'conversation_id': '1558872612540907520',
#   'geo': {'place_id': '315b740b108481f6',
#    'coordinates': {'type': 'Point', 'coordinates': [-2.2463, 53.4793]}}},
#  {'id': '1558830828259385344',
#   'created_at': '2022-08-14T15:00:05.000Z',
#   'author_id': '419663786',
#   'text': "Life's a party, so dress for it!\n\nShirt, pants, sandals: @HM\nRing, watch: @Maisonsimons\n\n📸: @Tracey.jazmin\u2063\u2063\u2063\u2063\u2063\u2063\u2063\u2063\nModel: @lancedugay\u2063\u2063\u2063\u2063\u2063\u2063\n📍: Glenora building – Former @royal_alberta_museum https://t.co/CVxV2dczOl",
#   'public_metrics': {'retweet_count': 0,
#    'reply_count': 0,
#    'like_count': 0,
#    'quote_count': 0},
#   'reply_settings': 'everyone',
#   'lang': 'en',
#   'source': 'Emplifi',
#   'conversation_id': '1558830828259385344'},
#  {'id': '1558765315416174596',
#   'created_at': '2022-08-14T10:39:46.000Z',
#   'author_id': '1557223542625669121',
#   'text': 'Won the contest of the prettiest chick wearing @hm cute fits ! \nFashion styling Day2Night dress.  Nude colour casual dress truned into a sexy night club dress . Fashion Boss 💜 https://t.co/aCKc9GJh3j',
#   'public_metrics': {'retweet_count': 5,
#    'reply_count': 1,
#    'like_count': 13,
#    'quote_count': 0},
#   'reply_settings': 'everyone',
#   'lang': 'en',
#   'source': 'Twitter for Android',
#   'conversation_id': '1558765315416174596'},
#  {'id': '1558647641663279108',
#   'in_reply_to_user_id': '14399483',
#   'created_at': '2022-08-14T02:52:10.000Z',
#   'author_id': '321152335',
#   'text': '@hm your baby clothes are going to be the reason I have to go back to work and not be a stay at home mom 😅',
#   'public_metrics': {'retweet_count': 0,
#    'reply_count': 0,
#    'like_count': 0,
#    'quote_count': 0},
#   'reply_settings': 'everyone',
#   'lang': 'en',
#   'source': 'Twitter for iPhone',
#   'conversation_id': '1558647641663279108'}]

# %%
json_response['includes']
# Out:
# {'users': [{'id': '1525515243912298499',
#    'name': 'fashion of heartstopper',
#    'created_at': '2022-05-14T16:36:30.000Z',
#    'public_metrics': {'followers_count': 179,
#     'following_count': 19,
#     'tweet_count': 144,
#     'listed_count': 1},
#    'username': 'fashionofhs',
#    'description': '#1 source for all heartstopper cast and character clothing needs 👕👖👗👟',
#    'verified': False},
#   {'id': '912295575697203201',
#    'name': 'Abigail',
#    'created_at': '2017-09-25T12:39:49.000Z',
#    'public_metrics': {'followers_count': 4,
#     'following_count': 6,
#     'tweet_count': 263,
#     'listed_count': 0},
#    'username': 'Abigail91127920',
#    'description': 'Student & Muma ✨',
#    'verified': False},
#   {'id': '14399483',
#    'name': 'H&M',
#    'created_at': '2008-04-15T18:34:00.000Z',
#    'public_metrics': {'followers_count': 8011196,
#     'following_count': 327,
#     'tweet_count': 14001,
#     'listed_count': 10192},
#    'username': 'hm',
#    'description': 'Welcome to our #HM world – we’re all about fashion, fun and things that matter to us. Got a question? 👉@hm_custserv',
#    'verified': True},
#   {'id': '1549124854812639232',
#    'name': '22 Pretty Things',
#    'created_at': '2022-07-18T20:12:21.000Z',
#    'public_metrics': {'followers_count': 10,
#     'following_count': 35,
#     'tweet_count': 29,
#     'listed_count': 0},
#    'username': '22prettythings',
#    'description': 'Outfit inspirations and styling tips',
#    'verified': False},
#   {'id': '1443595240137449472',
#    'name': 'Your Rich BFF',
#    'created_at': '2021-09-30T15:15:34.000Z',
#    'public_metrics': {'followers_count': 543,
#     'following_count': 58,
#     'tweet_count': 346,
#     'listed_count': 1},
#    'username': 'Your_RichBFF',
#    'description': '💵 Wall Street Trader turned Finance Creator 📱 2.5M BFFs on TikTok + IG 🗞 Ft. @Bloomberg, @YahooFinance, @CNBC, @NASDAQ 💻',
#    'verified': True},
#   {'id': '2283241081',
#    'name': 'nishi john',
#    'created_at': '2014-01-09T07:47:48.000Z',
#    'public_metrics': {'followers_count': 9,
#     'following_count': 56,
#     'tweet_count': 28,
#     'listed_count': 1},
#    'username': 'nishijohn1',
#    'description': '',
#    'verified': False},
#   {'id': '2426396108',
#    'name': 'Mend It, Australia is Karen and Danny Ellis',
#    'created_at': '2014-04-04T00:42:10.000Z',
#    'public_metrics': {'followers_count': 1037,
#     'following_count': 1088,
#     'tweet_count': 10044,
#     'listed_count': 15},
#    'username': 'MendItAussie',
#    'description': "MIA's legacy project raises awareness of repair by sharing practical actions undertaken. We're advocating & campaigning for the right to repair #voicesforrepair",
#    'verified': False},
#   {'id': '87229885',
#    'name': 'Hannah Apps',
#    'created_at': '2009-11-03T16:46:55.000Z',
#    'public_metrics': {'followers_count': 470,
#     'following_count': 253,
#     'tweet_count': 2594,
#     'listed_count': 27},
#    'username': 'hannahivvy',
#    'description': 'Content Creator.  Southerner living in the North. Contact: hannah-ivy@hotmail.com Instagram: @hannahivvy',
#    'verified': False},
#   {'id': '419663786',
#    'name': 'Londonderry Mall',
#    'created_at': '2011-11-23T16:45:05.000Z',
#    'public_metrics': {'followers_count': 1288,
#     'following_count': 744,
#     'tweet_count': 4959,
#     'listed_count': 25},
#    'username': 'LondonderryMall',
#    'description': 'Featuring a diverse mix of stores & services for your lifestyle!',
#    'verified': False},
#   {'id': '1557223542625669121',
#    'name': 'Goddess Val',
#    'created_at': '2022-08-10T04:33:28.000Z',
#    'public_metrics': {'followers_count': 55,
#     'following_count': 72,
#     'tweet_count': 28,
#     'listed_count': 0},
#    'username': 'SuperiorDresses',
#    'description': "Fashion Stylist ! Expert in woman's clothing, Casual , baggy, cute ,boss outfits, latex outfits , dominatrix persona",
#    'verified': False},
#   {'id': '321152335',
#    'name': 'teresa jasko',
#    'created_at': '2011-06-21T03:18:27.000Z',
#    'public_metrics': {'followers_count': 518,
#     'following_count': 278,
#     'tweet_count': 24827,
#     'listed_count': 1},
#    'username': 'teresaa_jasko',
#    'description': 'There’s a time to cry and right now isn’t the time',
#    'verified': False}],
#  'places': [{'full_name': 'Manchester, England',
#    'country': 'United Kingdom',
#    'place_type': 'city',
#    'name': 'Manchester',
#    'country_code': 'GB',
#    'geo': {'type': 'Feature',
#     'bbox': [-2.319934, 53.343623, -2.147026, 53.5702824],
#     'properties': {}},
#    'id': '315b740b108481f6'}]}

# %%
json_response['meta']
# Out:
# {'newest_id': '1559284907788083204',
#  'oldest_id': '1558647641663279108',
#  'result_count': 10,
#  'next_token': 'b26v89c19zqg8o3fpz5nho3o2sarmyw82839y6zf73ji5'}

# %%
type(json_response['data'])
# Out:
# list

# %%
type(json_response['data'][0])
# Out:
# dict

# %%
df = pd.DataFrame(json_response['data'])

# %%
df
# Out:
#                     id                created_at            author_id  \
# 0  1559284907788083204  2022-08-15T21:04:26.000Z  1525515243912298499
# 1  1559270690381086721  2022-08-15T20:07:57.000Z   912295575697203201
# 2  1559246999165206530  2022-08-15T18:33:48.000Z  1549124854812639232
# 3  1559185096284016641  2022-08-15T14:27:49.000Z  1443595240137449472
# 4  1559123491324309504  2022-08-15T10:23:02.000Z           2283241081
# 5  1558984167085355008  2022-08-15T01:09:24.000Z           2426396108
# 6  1558872612540907520  2022-08-14T17:46:07.000Z             87229885
# 7  1558830828259385344  2022-08-14T15:00:05.000Z            419663786
# 8  1558765315416174596  2022-08-14T10:39:46.000Z  1557223542625669121
# 9  1558647641663279108  2022-08-14T02:52:10.000Z            321152335
#
#                                                 text  \
# 0  Corinna Brown - Short twill skirt in black/whi...
# 1  @hm when will the pants shown here be availabl...
# 2  #outfitoftheday @Macys jewelry @Coach handbag ...
# 3  Hot tip: @hm has a Garment Collection program ...
# 4  My sister who loves @hm shops every month from...
# 5  3/ We gladly accept hand-me-ups from family &a...
# 6  Here for linen, fresh whites and sandals 🕊\n\n...
# 7  Life's a party, so dress for it!\n\nShirt, pan...
# 8  Won the contest of the prettiest chick wearing...
# 9  @hm your baby clothes are going to be the reas...
#
#                                       public_metrics reply_settings lang  \
# 0  {'retweet_count': 1, 'reply_count': 0, 'like_c...       everyone   en
# 1  {'retweet_count': 0, 'reply_count': 0, 'like_c...       everyone   en
# 2  {'retweet_count': 0, 'reply_count': 0, 'like_c...       everyone   en
# 3  {'retweet_count': 1, 'reply_count': 0, 'like_c...       everyone   en
# 4  {'retweet_count': 0, 'reply_count': 1, 'like_c...       everyone   en
# 5  {'retweet_count': 0, 'reply_count': 0, 'like_c...       everyone   en
# 6  {'retweet_count': 0, 'reply_count': 0, 'like_c...       everyone   en
# 7  {'retweet_count': 0, 'reply_count': 0, 'like_c...       everyone   en
# 8  {'retweet_count': 5, 'reply_count': 1, 'like_c...       everyone   en
# 9  {'retweet_count': 0, 'reply_count': 0, 'like_c...       everyone   en
#
#                 source      conversation_id in_reply_to_user_id  \
# 0   Twitter for iPhone  1559284907788083204                 NaN
# 1   Twitter for iPhone  1559270690381086721            14399483
# 2  Twitter for Android  1559246999165206530                 NaN
# 3      Twitter Web App  1559185096284016641                 NaN
# 4   Twitter for iPhone  1559122718385385472          2283241081
# 5      Twitter Web App  1558977104275918848          2426396108
# 6            Instagram  1558872612540907520                 NaN
# 7              Emplifi  1558830828259385344                 NaN
# 8  Twitter for Android  1558765315416174596                 NaN
# 9   Twitter for iPhone  1558647641663279108            14399483
#
#                                    referenced_tweets  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  [{'type': 'replied_to', 'id': '155912271838538...
# 5  [{'type': 'replied_to', 'id': '155898135753084...
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#                                                  geo
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6  {'place_id': '315b740b108481f6', 'coordinates'...
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN

# %%
#next request

# %%
#Inputs for the request
bearer_token = auth()
headers = create_headers(bearer_token)
keyword = "@zara (dress OR dresses OR shirt OR shirts OR pants OR skirt OR skirts OR clothes) lang:en -is:retweet"
start_time = "2022-08-12T00:00:00.000Z"
end_time = "2022-08-16T00:00:00.000Z"
max_results = 10

# %%
url = create_url(keyword, start_time,end_time, max_results)

# %%
json_response = connect_to_endpoint(url[0], headers, url[1])
# Out:
# Endpoint Response Code: 200

# %%
json_response['data']
# Out:
# [{'public_metrics': {'retweet_count': 0,
#    'reply_count': 1,
#    'like_count': 0,
#    'quote_count': 0},
#   'lang': 'en',
#   'author_id': '243868052',
#   'in_reply_to_user_id': '346742249',
#   'created_at': '2022-08-15T23:31:49.000Z',
#   'conversation_id': '1559321996667895809',
#   'text': '@ZARA I ordered the 1st dress (only offered in paisley) and received the 2nd. Customer support refused to waive the return fee for a dress I did not order and told me that I “received the correct dress.” 🤯 Accusing your customers of lying isn’t a good look - please fix this. https://t.co/sJjM4PxuwG',
#   'source': 'Twitter for iPhone',
#   'id': '1559321996667895809',
#   'reply_settings': 'everyone'},
#  {'public_metrics': {'retweet_count': 0,
#    'reply_count': 0,
#    'like_count': 0,
#    'quote_count': 0},
#   'lang': 'en',
#   'author_id': '18142537',
#   'referenced_tweets': [{'type': 'replied_to', 'id': '1559315661565730817'}],
#   'in_reply_to_user_id': '18142537',
#   'created_at': '2022-08-15T23:10:42.000Z',
#   'conversation_id': '1559315661565730817',
#   'text': '.@Zara. The second thing that maybe you shouldn’t do is call over another colleague who doubles down and tells the kid clutching a pair of jeans that they need to go to the mens fitting room if trying on mens clothes (the jeans were from your womens department fyi) @ZARA_Care',
#   'source': 'Twitter Web App',
#   'id': '1559316683453448192',
#   'reply_settings': 'everyone'},
#  {'public_metrics': {'retweet_count': 0,
#    'reply_count': 1,
#    'like_count': 10,
#    'quote_count': 0},
#   'lang': 'en',
#   'author_id': '1245158946',
#   'created_at': '2022-08-15T20:00:01.000Z',
#   'conversation_id': '1559268696824193024',
#   'text': 'This is us kicking off the last week of Season 9!!!! 🥳\n\nMel\nOutfit: @ZARA \n\nLainey\xa0\nDress: @Simone_Rocha_\nShoes: @CHANEL \n\nCynthia\xa0\nTop: @The_Kooples\nPants: @aliceandolivia\nShoes: @SteveMadden\n\nAndrea\nDress: @31philliplim\nShoes: @GreymerOfficial\n\n#WhatWeWore #OOTD https://t.co/ElQ4xX0nUT',
#   'source': 'Twitter Web App',
#   'id': '1559268696824193024',
#   'reply_settings': 'everyone'},
#  {'public_metrics': {'retweet_count': 0,
#    'reply_count': 1,
#    'like_count': 0,
#    'quote_count': 0},
#   'lang': 'en',
#   'author_id': '117858927',
#   'in_reply_to_user_id': '346742249',
#   'created_at': '2022-08-15T18:22:32.000Z',
#   'conversation_id': '1559244161659932672',
#   'text': '@ZARA ilsym for my kids clothes but pls pls pls build a functioning website.',
#   'source': 'Twitter for iPhone',
#   'id': '1559244161659932672',
#   'reply_settings': 'everyone'},
#  {'public_metrics': {'retweet_count': 0,
#    'reply_count': 1,
#    'like_count': 4,
#    'quote_count': 0},
#   'lang': 'en',
#   'author_id': '1482476401747976194',
#   'referenced_tweets': [{'type': 'replied_to', 'id': '1559219376108306432'}],
#   'in_reply_to_user_id': '1482476401747976194',
#   'created_at': '2022-08-15T16:46:17.000Z',
#   'conversation_id': '1559219376108306432',
#   'text': '1/\nWeb3 Fashion by day 💃🏻  and NFT Fashion by night 🦸🏻\u200d♀️\n\n💃🏻 Day \n@MAVIONworld necklace\n@ZARA top, skirt\n@nike dunks, bag\n\n🦸🏻\u200d♀️ Night\n@ZARA Top, Blazer, Pants\n@Nike dunks\nBottega Bag\n\nWhich one do you like better?\n💃Day or 🦸\u200d♀️Night?\n\n#fashion #web3fashion #fitcheck https://t.co/3qb6ML7wJ2',
#   'source': 'Twitter Web App',
#   'id': '1559219940368027652',
#   'reply_settings': 'everyone'},
#  {'public_metrics': {'retweet_count': 0,
#    'reply_count': 0,
#    'like_count': 0,
#    'quote_count': 0},
#   'lang': 'en',
#   'author_id': '248489436',
#   'in_reply_to_user_id': '346742249',
#   'created_at': '2022-08-15T16:35:15.000Z',
#   'conversation_id': '1559217165387046914',
#   'text': '@ZARA I deserve a discount code or something. A free return label, and a refund isn’t enough. Now I have to wait 3-7 business days for that money back, and now I’m out a dress for my vacation. Without any real time to find a replacement. https://t.co/S16FERKGck',
#   'source': 'Twitter for iPhone',
#   'id': '1559217165387046914',
#   'reply_settings': 'everyone'},
#  {'public_metrics': {'retweet_count': 0,
#    'reply_count': 1,
#    'like_count': 0,
#    'quote_count': 0},
#   'lang': 'en',
#   'author_id': '248489436',
#   'created_at': '2022-08-15T16:33:24.000Z',
#   'conversation_id': '1559216697743216641',
#   'text': 'Ordered a dress for my vacation from @zara … tell me why this is what they sent me. https://t.co/pCEldoqXxV',
#   'source': 'Twitter for iPhone',
#   'id': '1559216697743216641',
#   'reply_settings': 'everyone'},
#  {'public_metrics': {'retweet_count': 0,
#    'reply_count': 0,
#    'like_count': 7,
#    'quote_count': 0},
#   'lang': 'en',
#   'author_id': '1502689995991269385',
#   'created_at': '2022-08-15T16:31:04.000Z',
#   'conversation_id': '1559216111031304192',
#   'text': 'Look at shirt in @ZARA when @goodmindsnft TV’s and breads, et cetera on these shirts??? Make these connects! Your art is Superior 💜 https://t.co/B8dAqVHbrb',
#   'source': 'Twitter for iPhone',
#   'id': '1559216111031304192',
#   'reply_settings': 'everyone'},
#  {'public_metrics': {'retweet_count': 0,
#    'reply_count': 2,
#    'like_count': 0,
#    'quote_count': 0},
#   'lang': 'en',
#   'author_id': '21354066',
#   'in_reply_to_user_id': '346742249',
#   'created_at': '2022-08-15T13:24:24.000Z',
#   'conversation_id': '1559169135317319681',
#   'text': '@ZARA shirt arriving creased to hell is one thing but burn marks on front and back? Immediate return #badquality https://t.co/xPYXDyd3wq',
#   'source': 'Twitter for iPhone',
#   'id': '1559169135317319681',
#   'reply_settings': 'everyone'},
#  {'public_metrics': {'retweet_count': 0,
#    'reply_count': 0,
#    'like_count': 2,
#    'quote_count': 0},
#   'lang': 'en',
#   'author_id': '847306909266788355',
#   'created_at': '2022-08-15T06:17:55.000Z',
#   'conversation_id': '1559061807125262337',
#   'text': 'Let your spirit Fly with Peace, Happiness and Positivity\nGreen is so cool, so zen and yet makes such a statement.\nShirt and Footwear @zara Pants @marksandspencerindia\n✨ #greenbeautyblogger #sass #sasswars #attitudegirls #greenfashion #wearinggreen #attitudeiseverything #AJ https://t.co/s2dn5SxcPi',
#   'source': 'Twitter for Android',
#   'id': '1559061807125262337',
#   'reply_settings': 'everyone'}]

# %%
df2 = pd.DataFrame(json_response['data'])

# %%
df2
# Out:
#                                       public_metrics lang  \
# 0  {'retweet_count': 0, 'reply_count': 1, 'like_c...   en
# 1  {'retweet_count': 0, 'reply_count': 0, 'like_c...   en
# 2  {'retweet_count': 0, 'reply_count': 1, 'like_c...   en
# 3  {'retweet_count': 0, 'reply_count': 1, 'like_c...   en
# 4  {'retweet_count': 0, 'reply_count': 1, 'like_c...   en
# 5  {'retweet_count': 0, 'reply_count': 0, 'like_c...   en
# 6  {'retweet_count': 0, 'reply_count': 1, 'like_c...   en
# 7  {'retweet_count': 0, 'reply_count': 0, 'like_c...   en
# 8  {'retweet_count': 0, 'reply_count': 2, 'like_c...   en
# 9  {'retweet_count': 0, 'reply_count': 0, 'like_c...   en
#
#              author_id  in_reply_to_user_id                created_at  \
# 0            243868052            346742249  2022-08-15T23:31:49.000Z
# 1             18142537             18142537  2022-08-15T23:10:42.000Z
# 2           1245158946                  NaN  2022-08-15T20:00:01.000Z
# 3            117858927            346742249  2022-08-15T18:22:32.000Z
# 4  1482476401747976194  1482476401747976194  2022-08-15T16:46:17.000Z
# 5            248489436            346742249  2022-08-15T16:35:15.000Z
# 6            248489436                  NaN  2022-08-15T16:33:24.000Z
# 7  1502689995991269385                  NaN  2022-08-15T16:31:04.000Z
# 8             21354066            346742249  2022-08-15T13:24:24.000Z
# 9   847306909266788355                  NaN  2022-08-15T06:17:55.000Z
#
#        conversation_id                                               text  \
# 0  1559321996667895809  @ZARA I ordered the 1st dress (only offered in...
# 1  1559315661565730817  .@Zara. The second thing that maybe you should...
# 2  1559268696824193024  This is us kicking off the last week of Season...
# 3  1559244161659932672  @ZARA ilsym for my kids clothes but pls pls pl...
# 4  1559219376108306432  1/\nWeb3 Fashion by day 💃🏻  and NFT Fashion by...
# 5  1559217165387046914  @ZARA I deserve a discount code or something. ...
# 6  1559216697743216641  Ordered a dress for my vacation from @zara … t...
# 7  1559216111031304192  Look at shirt in @ZARA when @goodmindsnft TV’s...
# 8  1559169135317319681  @ZARA shirt arriving creased to hell is one th...
# 9  1559061807125262337  Let your spirit Fly with Peace, Happiness and ...
#
#                 source                   id reply_settings  \
# 0   Twitter for iPhone  1559321996667895809       everyone
# 1      Twitter Web App  1559316683453448192       everyone
# 2      Twitter Web App  1559268696824193024       everyone
# 3   Twitter for iPhone  1559244161659932672       everyone
# 4      Twitter Web App  1559219940368027652       everyone
# 5   Twitter for iPhone  1559217165387046914       everyone
# 6   Twitter for iPhone  1559216697743216641       everyone
# 7   Twitter for iPhone  1559216111031304192       everyone
# 8   Twitter for iPhone  1559169135317319681       everyone
# 9  Twitter for Android  1559061807125262337       everyone
#
#                                    referenced_tweets
# 0                                                NaN
# 1  [{'type': 'replied_to', 'id': '155931566156573...
# 2                                                NaN
# 3                                                NaN
# 4  [{'type': 'replied_to', 'id': '155921937610830...
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN

# %%
#combining dataframes

# %%
df = df.append(df2,ignore_index=True,sort=False)

# %%
df
# Out:
#                      id                created_at            author_id  \
# 0   1559284907788083204  2022-08-15T21:04:26.000Z  1525515243912298499
# 1   1559270690381086721  2022-08-15T20:07:57.000Z   912295575697203201
# 2   1559246999165206530  2022-08-15T18:33:48.000Z  1549124854812639232
# 3   1559185096284016641  2022-08-15T14:27:49.000Z  1443595240137449472
# 4   1559123491324309504  2022-08-15T10:23:02.000Z           2283241081
# 5   1558984167085355008  2022-08-15T01:09:24.000Z           2426396108
# 6   1558872612540907520  2022-08-14T17:46:07.000Z             87229885
# 7   1558830828259385344  2022-08-14T15:00:05.000Z            419663786
# 8   1558765315416174596  2022-08-14T10:39:46.000Z  1557223542625669121
# 9   1558647641663279108  2022-08-14T02:52:10.000Z            321152335
# 10  1559321996667895809  2022-08-15T23:31:49.000Z            243868052
# 11  1559316683453448192  2022-08-15T23:10:42.000Z             18142537
# 12  1559268696824193024  2022-08-15T20:00:01.000Z           1245158946
# 13  1559244161659932672  2022-08-15T18:22:32.000Z            117858927
# 14  1559219940368027652  2022-08-15T16:46:17.000Z  1482476401747976194
# 15  1559217165387046914  2022-08-15T16:35:15.000Z            248489436
# 16  1559216697743216641  2022-08-15T16:33:24.000Z            248489436
# 17  1559216111031304192  2022-08-15T16:31:04.000Z  1502689995991269385
# 18  1559169135317319681  2022-08-15T13:24:24.000Z             21354066
# 19  1559061807125262337  2022-08-15T06:17:55.000Z   847306909266788355
#
#                                                  text  \
# 0   Corinna Brown - Short twill skirt in black/whi...
# 1   @hm when will the pants shown here be availabl...
# 2   #outfitoftheday @Macys jewelry @Coach handbag ...
# 3   Hot tip: @hm has a Garment Collection program ...
# 4   My sister who loves @hm shops every month from...
# 5   3/ We gladly accept hand-me-ups from family &a...
# 6   Here for linen, fresh whites and sandals 🕊\n\n...
# 7   Life's a party, so dress for it!\n\nShirt, pan...
# 8   Won the contest of the prettiest chick wearing...
# 9   @hm your baby clothes are going to be the reas...
# 10  @ZARA I ordered the 1st dress (only offered in...
# 11  .@Zara. The second thing that maybe you should...
# 12  This is us kicking off the last week of Season...
# 13  @ZARA ilsym for my kids clothes but pls pls pl...
# 14  1/\nWeb3 Fashion by day 💃🏻  and NFT Fashion by...
# 15  @ZARA I deserve a discount code or something. ...
# 16  Ordered a dress for my vacation from @zara … t...
# 17  Look at shirt in @ZARA when @goodmindsnft TV’s...
# 18  @ZARA shirt arriving creased to hell is one th...
# 19  Let your spirit Fly with Peace, Happiness and ...
#
#                                        public_metrics reply_settings lang  \
# 0   {'retweet_count': 1, 'reply_count': 0, 'like_c...       everyone   en
# 1   {'retweet_count': 0, 'reply_count': 0, 'like_c...       everyone   en
# 2   {'retweet_count': 0, 'reply_count': 0, 'like_c...       everyone   en
# 3   {'retweet_count': 1, 'reply_count': 0, 'like_c...       everyone   en
# 4   {'retweet_count': 0, 'reply_count': 1, 'like_c...       everyone   en
# 5   {'retweet_count': 0, 'reply_count': 0, 'like_c...       everyone   en
# 6   {'retweet_count': 0, 'reply_count': 0, 'like_c...       everyone   en
# 7   {'retweet_count': 0, 'reply_count': 0, 'like_c...       everyone   en
# 8   {'retweet_count': 5, 'reply_count': 1, 'like_c...       everyone   en
# 9   {'retweet_count': 0, 'reply_count': 0, 'like_c...       everyone   en
# 10  {'retweet_count': 0, 'reply_count': 1, 'like_c...       everyone   en
# 11  {'retweet_count': 0, 'reply_count': 0, 'like_c...       everyone   en
# 12  {'retweet_count': 0, 'reply_count': 1, 'like_c...       everyone   en
# 13  {'retweet_count': 0, 'reply_count': 1, 'like_c...       everyone   en
# 14  {'retweet_count': 0, 'reply_count': 1, 'like_c...       everyone   en
# 15  {'retweet_count': 0, 'reply_count': 0, 'like_c...       everyone   en
# 16  {'retweet_count': 0, 'reply_count': 1, 'like_c...       everyone   en
# 17  {'retweet_count': 0, 'reply_count': 0, 'like_c...       everyone   en
# 18  {'retweet_count': 0, 'reply_count': 2, 'like_c...       everyone   en
# 19  {'retweet_count': 0, 'reply_count': 0, 'like_c...       everyone   en
#
#                  source      conversation_id  in_reply_to_user_id  \
# 0    Twitter for iPhone  1559284907788083204                  NaN
# 1    Twitter for iPhone  1559270690381086721             14399483
# 2   Twitter for Android  1559246999165206530                  NaN
# 3       Twitter Web App  1559185096284016641                  NaN
# 4    Twitter for iPhone  1559122718385385472           2283241081
# 5       Twitter Web App  1558977104275918848           2426396108
# 6             Instagram  1558872612540907520                  NaN
# 7               Emplifi  1558830828259385344                  NaN
# 8   Twitter for Android  1558765315416174596                  NaN
# 9    Twitter for iPhone  1558647641663279108             14399483
# 10   Twitter for iPhone  1559321996667895809            346742249
# 11      Twitter Web App  1559315661565730817             18142537
# 12      Twitter Web App  1559268696824193024                  NaN
# 13   Twitter for iPhone  1559244161659932672            346742249
# 14      Twitter Web App  1559219376108306432  1482476401747976194
# 15   Twitter for iPhone  1559217165387046914            346742249
# 16   Twitter for iPhone  1559216697743216641                  NaN
# 17   Twitter for iPhone  1559216111031304192                  NaN
# 18   Twitter for iPhone  1559169135317319681            346742249
# 19  Twitter for Android  1559061807125262337                  NaN
#
#                                     referenced_tweets  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4   [{'type': 'replied_to', 'id': '155912271838538...
# 5   [{'type': 'replied_to', 'id': '155898135753084...
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11  [{'type': 'replied_to', 'id': '155931566156573...
# 12                                                NaN
# 13                                                NaN
# 14  [{'type': 'replied_to', 'id': '155921937610830...
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
#
#                                                   geo
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6   {'place_id': '315b740b108481f6', 'coordinates'...
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN

# %%
df.to_csv('../data/tweet_dataset.csv', index=False)
