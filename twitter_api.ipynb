# %% [markdown]
# https://towardsdatascience.com/an-extensive-guide-to-collecting-tweets-from-twitter-api-v2-for-academic-research-using-python-3-518fcb71df2a

# %%
# For sending GET requests from the API
import requests
# For saving access tokens and for file management when creating and adding to the dataset
import os
# For dealing with json responses we receive from the API
import json
# For displaying the data after
import pandas as pd
# For saving the response data in CSV format
import csv
# For parsing the dates received from twitter in readable formats
import datetime
import dateutil.parser
import unicodedata
#To add wait time between requests
import time

# %%
os.environ['TOKEN'] = 'AAAAAAAAAAAAAAAAAAAAAKVLfwEAAAAA9U65FTL2ZrQgx1u1kgA94uCDzt8%3D9g59OKwN90CZ3BeWlqsMQfoFkLzUWhk7oYfz5917X90ygMxium'

# %%
def auth():
    return os.getenv('TOKEN')

# %%
def create_headers(bearer_token):
    headers = {"Authorization": "Bearer {}".format(bearer_token)}
    return headers

# %%
def create_url(keyword, start_date, end_date, max_results = 10):
    
    search_url = "https://api.twitter.com/2/tweets/search/recent" #Change to the endpoint you want to collect data from

    #change params based on the endpoint you are using
    query_params = {'query': keyword,
                    'start_time': start_date,
                    'end_time': end_date,
                    'max_results': max_results,
                    'expansions': 'author_id,in_reply_to_user_id,geo.place_id',
                    'tweet.fields': 'id,text,author_id,in_reply_to_user_id,geo,conversation_id,created_at,lang,public_metrics,referenced_tweets,reply_settings,source',
                    'user.fields': 'id,name,username,created_at,description,public_metrics,verified',
                    'place.fields': 'full_name,id,country,country_code,geo,name,place_type',
                    'next_token': {}}
    return (search_url, query_params)

# %%
def connect_to_endpoint(url, headers, params, next_token = None):
    params['next_token'] = next_token   #params object received from create_url function
    response = requests.request("GET", url, headers = headers, params = params)
    print("Endpoint Response Code: " + str(response.status_code))
    if response.status_code != 200:
        raise Exception(response.status_code, response.text)
    return response.json()

# %%
#Inputs for the request
bearer_token = auth()
headers = create_headers(bearer_token)
keyword = "@aerie lang:en -is:retweet"
start_time = "2022-08-06T00:00:00.000Z"
end_time = "2022-08-11T00:00:00.000Z"
max_results = 15

# %%
url = create_url(keyword, start_time,end_time, max_results)

# %%
json_response = connect_to_endpoint(url[0], headers, url[1])
# Out:
# Endpoint Response Code: 200

# %%
print(json.dumps(json_response, indent=4, sort_keys=True))
# Out:
# {
#     "data": [
#         {
#             "author_id": "19499305",
#             "conversation_id": "1557516176409956353",
#             "created_at": "2022-08-10T23:56:08.000Z",
#             "id": "1557516176409956353",
#             "in_reply_to_user_id": "28668072",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 1,
#                 "retweet_count": 0
#             },
#             "reply_settings": "everyone",
#             "source": "Twitter for iPhone",
#             "text": "@Aerie I ordered a Henley online in a size large. It got delivered yesterday and I opened it today and the price tag says L but the actual shirt is a M. What do. I need to do? I\u2019m super sad. https://t.co/wrEAZpODf9"
#         },
#         {
#             "author_id": "18108977",
#             "conversation_id": "1557493407135801345",
#             "created_at": "2022-08-10T23:47:55.000Z",
#             "id": "1557514111067504640",
#             "in_reply_to_user_id": "2304692598",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1557493407135801345",
#                     "type": "replied_to"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter Web App",
#             "text": "@designnymph @Aerie @LaserShip just mentioned u on this live show off this tweet https://t.co/kLffZ6SPwl"
#         },
#         {
#             "author_id": "21720566",
#             "conversation_id": "1555313225322958849",
#             "created_at": "2022-08-10T22:41:21.000Z",
#             "id": "1557497355045412865",
#             "in_reply_to_user_id": "543401743",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 1,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1557496827464716291",
#                     "type": "replied_to"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter for iPhone",
#             "text": "@Mori_Blu @Aerie Perfect, thank you! I always use cold water! \u263a\ufe0f"
#         },
#         {
#             "author_id": "543401743",
#             "conversation_id": "1555313225322958849",
#             "created_at": "2022-08-10T22:39:15.000Z",
#             "id": "1557496827464716291",
#             "in_reply_to_user_id": "21720566",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 1,
#                 "retweet_count": 0
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1557485161318596610",
#                     "type": "replied_to"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter for iPad",
#             "text": "@xomichelle @Aerie I washed the blue and the green and no color transfer\u2026I wash cold, though. Hope that helps ^_^"
#         },
#         {
#             "author_id": "21720566",
#             "conversation_id": "1555176528882827264",
#             "created_at": "2022-08-10T22:37:09.000Z",
#             "id": "1557496298831486979",
#             "in_reply_to_user_id": "887344118887845890",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 1,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1557490785213239296",
#                     "type": "replied_to"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter for iPhone",
#             "text": "@Briediann @AEO @Aerie I\u2019ve unknowingly had packages delivered from them before (old navy and barnes &amp; noble) after searching my emails. Luckily those were delivered without any issue but after our recent issue with them and googling to find lots of other issues, that\u2019s why I sat outside."
#         },
#         {
#             "author_id": "2304692598",
#             "conversation_id": "1557493407135801345",
#             "created_at": "2022-08-10T22:25:39.000Z",
#             "id": "1557493407135801345",
#             "in_reply_to_user_id": "28668072",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 2,
#                 "retweet_count": 0
#             },
#             "reply_settings": "everyone",
#             "source": "Twitter for iPhone",
#             "text": "@Aerie I know you claim to have some concern about your environmental footprint\u2026 if that\u2019s true you may need a new shipping company! @LaserShip seems to not care about their carbon footprint sending packages literally past it\u2019s location up and down the east coast for no reason https://t.co/gBLYusoiZB"
#         },
#         {
#             "author_id": "887344118887845890",
#             "conversation_id": "1555176528882827264",
#             "created_at": "2022-08-10T22:15:14.000Z",
#             "id": "1557490785213239296",
#             "in_reply_to_user_id": "21720566",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 1,
#                 "retweet_count": 0
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1557486924302098432",
#                     "type": "replied_to"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter for iPhone",
#             "text": "@xomichelle @AEO @Aerie It\u2019s was my first time using them so I was clueless how bad it is. I love Aerie and I can\u2019t get to the mall often but I\u2019ll never order online again. I wont spend $100 on clothes without a guarantee I\u2019ll get them."
#         },
#         {
#             "author_id": "21720566",
#             "conversation_id": "1555176528882827264",
#             "created_at": "2022-08-10T21:59:54.000Z",
#             "id": "1557486924302098432",
#             "in_reply_to_user_id": "887344118887845890",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 1,
#                 "retweet_count": 0
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1555176528882827264",
#                     "type": "replied_to"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter for iPhone",
#             "text": "@Briediann @AEO @Aerie I literally sat on my front porch the other day when I saw my Aerie package was being delivered by them. Sad but I know people have nothing but trouble with them! I will only order for store pickup from now on. We had a previous package stolen by them."
#         },
#         {
#             "author_id": "21720566",
#             "conversation_id": "1555313225322958849",
#             "created_at": "2022-08-10T21:52:53.000Z",
#             "id": "1557485161318596610",
#             "in_reply_to_user_id": "543401743",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 1,
#                 "quote_count": 0,
#                 "reply_count": 1,
#                 "retweet_count": 0
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1555313225322958849",
#                     "type": "replied_to"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter for iPhone",
#             "text": "@Mori_Blu @Aerie I just got this same shirt! Just wondering, if you\u2019ve washed it in the washing machine with other clothes, did it bleed from any of the dyes? Just trying to figure out if I should continue hand washing my clothes from Aerie or not."
#         },
#         {
#             "author_id": "1537879358156574720",
#             "conversation_id": "1391880439644655620",
#             "created_at": "2022-08-10T19:30:08.000Z",
#             "id": "1557449236622483465",
#             "in_reply_to_user_id": "1201260835810754561",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1391880439644655620",
#                     "type": "replied_to"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter Web App",
#             "text": "@ameliexrose @Aerie Who is bord  too ..."
#         },
#         {
#             "author_id": "2870708554",
#             "conversation_id": "1557434904073277440",
#             "created_at": "2022-08-10T18:37:53.000Z",
#             "id": "1557436088410464256",
#             "in_reply_to_user_id": "2870708554",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 13,
#                 "quote_count": 0,
#                 "reply_count": 1,
#                 "retweet_count": 0
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1557435349697040384",
#                     "type": "replied_to"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter for Android",
#             "text": "When I told people I wanted to establish a library in an area that is still terrorized by Turkish airstrikes, people looked at me like I was insane. Then @Aerie wrote me a $20k check. Shoot your shot, &amp; don't fall into the trap of self-rejecting your wildest dreams. /fin"
#         },
#         {
#             "author_id": "1059265803974008833",
#             "conversation_id": "1557402591880945664",
#             "created_at": "2022-08-10T16:24:47.000Z",
#             "id": "1557402591880945664",
#             "in_reply_to_user_id": "28668072",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "reply_settings": "everyone",
#             "source": "Twitter for iPhone",
#             "text": "@Aerie pls restock the patchwork triangle bikini top \ud83e\udd72"
#         },
#         {
#             "author_id": "1277261987840503808",
#             "conversation_id": "1557380612150988802",
#             "created_at": "2022-08-10T14:57:27.000Z",
#             "id": "1557380612150988802",
#             "in_reply_to_user_id": "28668072",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "reply_settings": "everyone",
#             "source": "Twitter Web App",
#             "text": "@Aerie When did you stop using normal sized models? Very disappointed you decided to stop being body positive"
#         },
#         {
#             "author_id": "1536361441539854336",
#             "conversation_id": "1391880439644655620",
#             "created_at": "2022-08-10T14:04:34.000Z",
#             "id": "1557367302978420739",
#             "in_reply_to_user_id": "1201260835810754561",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1391880439644655620",
#                     "type": "replied_to"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter Web App",
#             "text": "@ameliexrose @Aerie Are you as bored as I am in  this quaraantine?"
#         },
#         {
#             "author_id": "1255848356",
#             "conversation_id": "1557164767013351425",
#             "created_at": "2022-08-10T00:39:45.000Z",
#             "id": "1557164767013351425",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 7,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "reply_settings": "everyone",
#             "source": "Twitter for iPhone",
#             "text": "hi twitter i\u2019m an #aerieambassador now \ud83e\udd70\ud83d\udc9e\ud83d\udc96\ud83d\udc95\ud83d\udc97\ud83d\udc9a @Aerie #aeriereal https://t.co/voJxb5kIeE"
#         }
#     ],
#     "includes": {
#         "users": [
#             {
#                 "created_at": "2009-01-25T18:52:57.000Z",
#                 "description": "\u2022 559 \u21e2 615 \u2022 mama \u2022 6w7 \u2022 love every moment \u2022",
#                 "id": "19499305",
#                 "name": "Stephaney Ann Denton",
#                 "public_metrics": {
#                     "followers_count": 121,
#                     "following_count": 113,
#                     "listed_count": 0,
#                     "tweet_count": 11124
#                 },
#                 "username": "stephaneyann",
#                 "verified": false
#             },
#             {
#                 "created_at": "2009-04-03T22:14:23.000Z",
#                 "description": "Power. Positivity. No retouching. #AerieREAL New OFFLINE by Aerie, activewear made for REAL life. #goingOFFLINE Shop intimates, swim & activewear.",
#                 "id": "28668072",
#                 "name": "Aerie",
#                 "public_metrics": {
#                     "followers_count": 94902,
#                     "following_count": 1246,
#                     "listed_count": 451,
#                     "tweet_count": 28634
#                 },
#                 "username": "Aerie",
#                 "verified": true
#             },
#             {
#                 "created_at": "2008-12-14T01:46:18.000Z",
#                 "description": "Content Creator/Consultant,Actor,DJ,Producer/Social Media & YT Editor -Contact HireDjDelz@gmail.com  cash app : $REALDJDELZ\nSome links posted at affiliate links",
#                 "id": "18108977",
#                 "name": "DJ DELZ aka THE SNEAKER ADDICT",
#                 "public_metrics": {
#                     "followers_count": 15784,
#                     "following_count": 1268,
#                     "listed_count": 313,
#                     "tweet_count": 240252
#                 },
#                 "username": "djdelz",
#                 "verified": false
#             },
#             {
#                 "created_at": "2014-01-22T11:33:06.000Z",
#                 "description": "\u2649\ufe0f ~ Will fight for EU level benefits and social programs ~MSW ~MArch by RIBA ~ stuck in the US since no other country wants us!",
#                 "id": "2304692598",
#                 "name": "Designnymph",
#                 "public_metrics": {
#                     "followers_count": 41,
#                     "following_count": 305,
#                     "listed_count": 0,
#                     "tweet_count": 3001
#                 },
#                 "username": "designnymph",
#                 "verified": false
#             },
#             {
#                 "created_at": "2009-02-24T02:23:22.000Z",
#                 "description": "29 \u2728 she/her \ud83c\udf38 11.06.15 \ud83d\udc95 lilycove \ud83c\udf4e\ud83c\udf3a",
#                 "id": "21720566",
#                 "name": "Michelle \ud83d\udc95",
#                 "public_metrics": {
#                     "followers_count": 340,
#                     "following_count": 659,
#                     "listed_count": 10,
#                     "tweet_count": 40061
#                 },
#                 "username": "xomichelle",
#                 "verified": false
#             },
#             {
#                 "created_at": "2012-04-02T13:14:04.000Z",
#                 "description": "#Soulsborne #Bisexual\ud83c\udf08 #Introvert. Native. Weird. smol. Hopeful Voice Actor. Sometimes GROMP. #BlackLivesMatter \ud83d\udc3a she/her\ud83d\udd79\ud83c\udf63\u2696\ufe0f\ud83d\udc08\ud83d\uddf3 $MoriBlu",
#                 "id": "543401743",
#                 "name": "MoriBlu - dismantle SCOTUS",
#                 "public_metrics": {
#                     "followers_count": 856,
#                     "following_count": 505,
#                     "listed_count": 31,
#                     "tweet_count": 26646
#                 },
#                 "username": "Mori_Blu",
#                 "verified": false
#             },
#             {
#                 "created_at": "2017-07-18T16:11:38.000Z",
#                 "description": "Oh, hey. @SpaceAnimaI = \ud83d\udc95",
#                 "id": "887344118887845890",
#                 "name": "Brie Tosolini-Puckett",
#                 "public_metrics": {
#                     "followers_count": 29,
#                     "following_count": 287,
#                     "listed_count": 1,
#                     "tweet_count": 510
#                 },
#                 "username": "Briediann",
#                 "verified": false
#             },
#             {
#                 "created_at": "2022-06-17T19:26:40.000Z",
#                 "description": "Guys, I don\u2019t chat  on Twitter. find me  there, and a couple of my hot videos;)",
#                 "id": "1537879358156574720",
#                 "name": "ConcepcionRivas",
#                 "public_metrics": {
#                     "followers_count": 10,
#                     "following_count": 15,
#                     "listed_count": 0,
#                     "tweet_count": 1448
#                 },
#                 "username": "Concepcio_Rivas",
#                 "verified": false
#             },
#             {
#                 "created_at": "2019-12-01T22:04:43.000Z",
#                 "description": "use ur voice kiddos. // she/her",
#                 "id": "1201260835810754561",
#                 "name": "amelie",
#                 "public_metrics": {
#                     "followers_count": 383166,
#                     "following_count": 83,
#                     "listed_count": 181,
#                     "tweet_count": 4998
#                 },
#                 "username": "ameliexrose",
#                 "verified": true
#             },
#             {
#                 "created_at": "2014-11-10T15:06:24.000Z",
#                 "description": "\ud83c\udf0d Humanitarian aid worker | #UAP Advocate | \ud83c\udff3\ufe0f\u200d\ud83c\udf08  '21 @OutinNatSec Leader | '20 @Aerie Changemaker COMING \ud83d\udd1c: Ontologically Speaking @ontologicalpod",
#                 "id": "2870708554",
#                 "name": "Katie Howland, MPH (she/her)",
#                 "public_metrics": {
#                     "followers_count": 1776,
#                     "following_count": 497,
#                     "listed_count": 23,
#                     "tweet_count": 2567
#                 },
#                 "username": "katieshowland",
#                 "verified": false
#             },
#             {
#                 "created_at": "2018-11-05T02:07:02.000Z",
#                 "description": "we out here",
#                 "id": "1059265803974008833",
#                 "name": "thyroid",
#                 "public_metrics": {
#                     "followers_count": 19,
#                     "following_count": 25,
#                     "listed_count": 0,
#                     "tweet_count": 217
#                 },
#                 "username": "thyroidbanks",
#                 "verified": false
#             },
#             {
#                 "created_at": "2020-06-28T15:26:16.000Z",
#                 "description": "I\u2019m independent, loath big brother, hate cancel culture and love facts. I\u2019m pro social equality, but anti the PC police and outrage culture.",
#                 "id": "1277261987840503808",
#                 "name": "fromsarah",
#                 "public_metrics": {
#                     "followers_count": 19,
#                     "following_count": 181,
#                     "listed_count": 0,
#                     "tweet_count": 452
#                 },
#                 "username": "fromsarah2",
#                 "verified": false
#             },
#             {
#                 "created_at": "2022-06-13T14:54:59.000Z",
#                 "description": "Do you want to spend time in the company of a liberated nympho girl? writ to me. link below",
#                 "id": "1536361441539854336",
#                 "name": "ChandraBoyer",
#                 "public_metrics": {
#                     "followers_count": 14,
#                     "following_count": 95,
#                     "listed_count": 0,
#                     "tweet_count": 1573
#                 },
#                 "username": "Chandra_Boyer",
#                 "verified": false
#             },
#             {
#                 "created_at": "2013-03-10T01:58:09.000Z",
#                 "description": "dontcha wish ur girlfriend was hot like leigh \ud83d\ude2b // all opinions are m\u0336y\u0336 \u0336o\u0336w\u0336n\u0336 sexy",
#                 "id": "1255848356",
#                 "name": "Leigh \ud83d\udc9e",
#                 "public_metrics": {
#                     "followers_count": 415,
#                     "following_count": 260,
#                     "listed_count": 1,
#                     "tweet_count": 1319
#                 },
#                 "username": "leighannhealey",
#                 "verified": false
#             }
#         ]
#     },
#     "meta": {
#         "newest_id": "1557516176409956353",
#         "next_token": "b26v89c19zqg8o3fpz5n27uovdlbfjx1ixh3gvhoczs71",
#         "oldest_id": "1557164767013351425",
#         "result_count": 15
#     }
# }

# %%
json_response['data'][0]['created_at']
# Out:
# '2022-08-10T23:56:08.000Z'

# %%
# Create file
tweets = open("data.csv", "a", newline="", encoding='utf-8')
csvWriter = csv.writer(tweets)

#Create headers for the data you want to save, in this example, we only want save these columns in our dataset
csvWriter.writerow(['author id', 'created_at', 'geo', 'id','lang', 'like_count', 'quote_count', 'reply_count','retweet_count','source','tweet'])
tweets.close()

# %%
def append_to_csv(json_response, fileName):

    #A counter variable
    counter = 0

    #Open OR create the target CSV file
    tweets = open(fileName, "a", newline="", encoding='utf-8')
    csvWriter = csv.writer(tweets)

    #Loop through each tweet
    for tweet in json_response['data']:
        
        # We will create a variable for each since some of the keys might not exist for some tweets
        # So we will account for that

        # 1. Author ID
        author_id = tweet['author_id']

        # 2. Time created
        created_at = dateutil.parser.parse(tweet['created_at'])

        # 3. Geolocation
        if ('geo' in tweet):   
            geo = tweet['geo']['place_id']
        else:
            geo = " "

        # 4. Tweet ID
        tweet_id = tweet['id']

        # 5. Language
        lang = tweet['lang']

        # 6. Tweet metrics
        retweet_count = tweet['public_metrics']['retweet_count']
        reply_count = tweet['public_metrics']['reply_count']
        like_count = tweet['public_metrics']['like_count']
        quote_count = tweet['public_metrics']['quote_count']

        # 7. source
        source = tweet['source']

        # 8. Tweet text
        text = tweet['text']
        
        # Assemble all data in a list
        res = [author_id, created_at, geo, tweet_id, lang, like_count, quote_count, reply_count, retweet_count, source, text]
        
        # Append the result to the CSV file
        csvWriter.writerow(res)
        counter += 1

    # When done, close the CSV file
    tweets.close()

    # Print the number of tweets for this iteration
    print("# of Tweets added from this response: ", counter)

# %%
append_to_csv(json_response, "tweets.csv")
# Out:
# # of Tweets added from this response:  15

# %%
df = pd.read_csv('tweets.csv')

# %%
pd.set_option('display.max_colwidth', None)

# %%
df
# Out:
#      849670936924172289  2022-08-08 23:59:43+00:00     1556792300998639618  \
# 0   1174554679822307329  2022-08-08 23:59:30+00:00     1556792249106644992
# 1   1236458791962644480  2022-08-08 23:59:22+00:00     1556792215120265217
# 2   1306498176854175744  2022-08-08 23:59:19+00:00     1556792202524872704
# 3   1357815347991183366  2022-08-08 23:58:34+00:00     1556792011734261763
# 4   1376947999901937671  2022-08-08 23:58:29+00:00     1556791994327781377
# ..                  ...                        ... ..                  ...
# 81           2870708554  2022-08-10 18:37:53+00:00     1557436088410464256
# 82  1059265803974008833  2022-08-10 16:24:47+00:00     1557402591880945664
# 83  1277261987840503808  2022-08-10 14:57:27+00:00     1557380612150988802
# 84  1536361441539854336  2022-08-10 14:04:34+00:00     1557367302978420739
# 85           1255848356  2022-08-10 00:39:45+00:00     1557164767013351425
#
#     en   1  0  0.1  0.2   Twitter for iPhone  \
# 0   en   1  0    0    1   Twitter for iPhone
# 1   en   2  0    1    0  Twitter for Android
# 2   en   0  0    0    0   Twitter for iPhone
# 3   en   0  0    0    0   Twitter for iPhone
# 4   en   0  0    0    0             Poshmark
# ..  ..  .. ..  ...  ...                  ...
# 81  en  13  0    1    0  Twitter for Android
# 82  en   0  0    0    0   Twitter for iPhone
# 83  en   0  0    0    0      Twitter Web App
# 84  en   0  0    0    0      Twitter Web App
# 85  en   7  0    0    0   Twitter for iPhone
#
#                                                                                                                                                                                                                         same! she dresses like rich me would 😭😍 https://t.co/adQU7hKk1w
# 0                                                                                                                                                                                                                                                       @LionBrosPodcast Summer dresses
# 1                                                                                                                   one direction, all time low, 5sos, the hunger games, the best marvel era, frozen, skater dresses and skinny jeans, everyone had the same white samsung galaxy s3...
# 2                                                                                                                                                I bought 2 dresses for 1 gala bc I just couldn't decide &amp; one might feel better on. It's my logic &amp; I won't apologize for it 😌
# 3                                                                                                                                                                                                                                  @gabrielafotoo @EmmetCohen He always dresses so well
# 4                                                                                                                                         Check out this listing I just added to my #Poshmark closet: Zara T-Shirt Maxi Dress Beige. https://t.co/gJUwbAKhWK #shopmycloset @poshmarkapp
# ..                                                                                                                                                                                                                                                                                  ...
# 81  When I told people I wanted to establish a library in an area that is still terrorized by Turkish airstrikes, people looked at me like I was insane. Then @Aerie wrote me a $20k check. Shoot your shot, &amp; don't fall into the trap of self-rejecting your wildest dreams. /fin
# 82                                                                                                                                                                                                                               @Aerie pls restock the patchwork triangle bikini top 🥲
# 83                                                                                                                                                                        @Aerie When did you stop using normal sized models? Very disappointed you decided to stop being body positive
# 84                                                                                                                                                                                                                   @ameliexrose @Aerie Are you as bored as I am in  this quaraantine?
# 85                                                                                                                                                                                              hi twitter i’m an #aerieambassador now 🥰💞💖💕💗💚 @Aerie #aeriereal https://t.co/voJxb5kIeE
#
# [86 rows x 11 columns]

# %%
#explored 15 tweets at ZARA, Everlane, Madewell, and Aerie, all clothing brands that are targeted towards women...
#tweets are mess/not high quality
